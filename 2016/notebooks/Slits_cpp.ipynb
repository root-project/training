// %% [markdown]
// # Tutorial: Drawing the interference pattern of light falling on a grid with n slits and a ratio of r of slit width over distance between slits in C++
//
// Translation to notebook by: Theis Hansen

// %% [markdown]
// In this tutorial, we are going to learn to code the aforementioned grid in C++
// To begin with, we need to import ROOT so that we can use the toolkit. We also set our Notebook to C++

// %% [markdown]
// ### Writing the Function
// We use ROOT Namespace TMath to access the mathimatical toolkit of ROOT. In this first line we are setting the value for our constant "pi", and we use the math toolkit to state that our "pi" is the mathimatical constant "Pi".

// %%
%jsroot on

// %%
auto pi = TMath::Pi()
// Out:
// (double) 3.14159

// %% [markdown]
// Here we are writing the code for our functions that we will call on later. The "*"s are pointers, that access a certain area of the memory (only in the first set of parentheses of each line, the others are multiplications).
//
// The "%%cpp -d" marks a cell as used for declaration of functions.

// %%
%%cpp -d
double single(double *x, double *par){return pow(sin(pi*par[0]*x[0])/(pi*par[0]*x[0]),2);};
double nslit0(double *x, double *par){return pow(sin(pi*par[1]*x[0])/sin(pi*x[0]),2);};
double nslit(double *x, double *par){return single(x,par) * nslit0(x,par);};

// %% [markdown]
// We set the number of slits to 4, and the ration of slit width to distance between slits to 2.

// %%
float r=.2,ns=2
// Out:
// (float) 2.00000f

// %% [markdown]
// Here we are using the ROOT Type TF1 to write our function and we add the "*" pointer before our Fnslit object so that the information can be saved to the computer's memory.
// We set the options for our function with the command SetNpx. Here we use the "->" because we are setting a command to an object with a pointer.

// %%
TF1 Fnslit("Fnslit",nslit,-5.001,5.,2);
Fnslit.SetNpx(500);

// %% [markdown]
// Here you can see that we are setting the parameters for the code, so that we can apply them as fixed variables that we state at the beginning of our code. This saves us the trouble of entering long numbers over and over again. Note that the parameter number starts at 0, not 1.

// %%
Fnslit.SetParameters(r,ns)

// %% [markdown]
// Now that we've got our code nicely written out, we can use the "Draw" command so that we can see the graph.

// %%
TCanvas c;
Fnslit.Draw();
c.Draw();
// Out:
// <div id="root_plot_1"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
//        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":36896776,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":1.000000e-01,"fRightMargin":1.000000e-01,"fBottomMargin":1.000000e-01,"fTopMargin":1.000000e-01,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":9.900000e-01,"fYstat":9.900000e-01,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-6.251125e+00,"fY1":-5.245262e-01,"fX2":6.250125e+00,"fY2":4.720736e+00,"fXtoAbsPixelk":3.480279e+02,"fXtoPixelk":3.480279e+02,"fXtoPixel":5.567443e+01,"fYtoAbsPixelk":4.248000e+02,"fYtoPixelk":4.248000e+02,"fYtoPixel":-8.998597e+01,"fUtoAbsPixelk":5.000000e-05,"fUtoPixelk":5.000000e-05,"fUtoPixel":696,"fVtoAbsPixelk":4.720000e+02,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-6.251125e+00,"fPixeltoXk":-6.251125e+00,"fPixeltoX":1.796157e-02,"fAbsPixeltoYk":4.720736e+00,"fPixeltoYk":-5.245262e-01,"fPixeltoY":-1.111284e-02,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-5.001000e+00,"fUymin":0,"fUxmax":5.000000e+00,"fUymax":4.196209e+00,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":-5.001000e+00,"fY1":0,"fX2":5.000000e+00,"fY2":4.196209e+00,"fBorderSize":1,"fBorderMode":0},{"_typename":"TF1","fUniqueID":0,"fBits":33554440,"fName":"Fnslit","fTitle":"Fnslit","fLineColor":2,"fLineStyle":1,"fLineWidth":3,"fFillColor":19,"fFillStyle":0,"fMarkerColor":600,"fMarkerStyle":8,"fMarkerSize":5.000000e-01,"fXmin":-5.001000e+00,"fXmax":5,"fNpar":2,"fNdim":1,"fNpx":500,"fType":1,"fNpfits":0,"fNDF":0,"fChisquare":0,"fMinimum":-1111,"fMaximum":-1111,"fParErrors":[0,0],"fParMin":[0,0],"fParMax":[0,0],"fSave":[1.599583e-07,5.800337e-05,2.435088e-04,5.508250e-04,9.680629e-04,1.477663e-03,2.057006e-03,2.679263e-03,3.314449e-03,3.930672e-03,4.495524e-03,4.977594e-03,5.348033e-03,5.582153e-03,5.660976e-03,5.572715e-03,5.314096e-03,4.891511e-03,4.321923e-03,3.633496e-03,2.865908e-03,2.070323e-03,1.308992e-03,6.544797e-04,1.885065e-04,4.238428e-07,1.853326e-04,8.418800e-04,2.069773e-03,3.967061e-03,6.627237e-03,1.013624e-02,1.456942e-02,1.998855e-02,2.643894e-02,3.394680e-02,4.251685e-02,5.213036e-02,6.274354e-02,7.428653e-02,8.666291e-02,9.974987e-02,1.133990e-01,1.274376e-01,1.416712e-01,1.558861e-01,1.698528e-01,1.833304e-01,1.960709e-01,2.078243e-01,2.183445e-01,2.273946e-01,2.347529e-01,2.402193e-01,2.436205e-01,2.448162e-01,2.437041e-01,2.402249e-01,2.343663e-01,2.261662e-01,2.157157e-01,2.031602e-01,1.887001e-01,1.725900e-01,1.551369e-01,1.366972e-01,1.176725e-01,9.850407e-02,7.966629e-02,6.165923e-02,4.500012e-02,3.021396e-02,1.782365e-02,8.339510e-03,2.248594e-03,3.855386e-06,2.013482e-03,8.630572e-03,2.014339e-02,3.676640e-02,5.863236e-02,8.578558e-02,1.181766e-01,1.556586e-01,1.979849e-01,2.448096e-01,2.956885e-01,3.500831e-01,4.073665e-01,4.668305e-01,5.276954e-01,5.891215e-01,6.502212e-01,7.100742e-01,7.677423e-01,8.222867e-01,8.727844e-01,9.183464e-01,9.581353e-01,9.913826e-01,1.017405e+00,1.035623e+00,1.045571e+00,1.046913e+00,1.039456e+00,1.023154e+00,9.981174e-01,9.646183e-01,9.230884e-01,8.741191e-01,8.184566e-01,7.569938e-01,6.907600e-01,6.209069e-01,5.486929e-01,4.754640e-01,4.026331e-01,3.316572e-01,2.640128e-01,2.011710e-01,1.445704e-01,9.559156e-02,5.553010e-02,2.557149e-02,6.766599e-03,8.994584e-06,6.014413e-03,2.530273e-02,5.818291e-02,1.047413e-01,1.648333e-01,2.380795e-01,3.238651e-01,4.213438e-01,5 ...
